# %% [markdown]
# ## Challenge 1: Tuples
#
# #### Do you know you can create tuples with only one element?
#
# **In the cell below, define a variable `tup` with a single element `"I"`.**
#
# *Hint: you need to add a comma (`,`) after the single element.*

# %%
# Your code here
tupa = ('I',)
print(tupa)
# Out:
# ('I',)

# %% [markdown]
# #### Print the type of `tup`.
#
# Make sure its type is correct (i.e. *tuple* instead of *str*).

# %%
# Your code here
print('Variable tup belongs to: ', type(tupa),'.')
# Out:
# Variable tup belongs to:  <class 'tuple'> .

# %% [markdown]
# #### Now try to append the following elements to `tup`.
#
# Are you able to do it? Explain.
#
# ```
# "r", "o", "n", "h", "a", "c", "k',
# ```

# %%
# Your code here

tupa.append("r", "o", "n", "h", "a", "c", "k",)

# Your explanation here
# Not possible: error message:AttributeError: 'tuple' object has no attribute 'append'.
# Tuples are a type of non-primitive data structure which is immutable.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-7df0f05eda24> in <module>
#       1 # Your code here
#       2
# ----> 3 tupa.append("r", "o", "n", "h", "a", "c", "k",)
#       4
#       5 # Your explanation here
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# #### How about re-assign a new value to an existing tuple?
#
# Re-assign the following elements to `tup`. Are you able to do it? Explain.
#
# ```
# "I", "r", "o", "n", "h", "a", "c", "k"
# ```

# %%
# Your code here
tupa = ("I", "r", "o", "n", "h", "a", "c", "k")
print(tupa)
# Your explanation here
# Was able to re-assign tuple 'tup'.
#Although tuples are immutable, by re-assigning varial 'tup', original tuple 'tup' was overwritten instead of been modifiled.
# Out:
# ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k')

# %% [markdown]
# #### Split `tup` into `tup1` and `tup2` with 4 elements in each.
#
# `tup1` should be `("I", "r", "o", "n")` and `tup2` should be `("h", "a", "c", "k")`.
#
# *Hint: use positive index numbers for `tup1` assignment and use negative index numbers for `tup2` assignment. Positive index numbers count from the beginning whereas negative index numbers count from the end of the sequence.*
#
# Also print `tup1` and `tup2`.

# %%
# Your code here
tup1 = tupa[0:4]
print('tup1 = ', tup1)
tup2 = tupa[-4:]
print('tup2 = ', tup2)
# Out:
# tup1 =  ('I', 'r', 'o', 'n')
# tup2 =  ('h', 'a', 'c', 'k')

# %% [markdown]
# #### Add `tup1` and `tup2` into `tup3` using the `+` operator.
#
# Then print `tup3` and check if `tup3` equals to `tup`.

# %%
# Your code here
tup3 = tup1 + tup2
print(tup3)
if tup3 == tupa:
    print('tup3 equals to tupa')
# Out:
# ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k')
# tup3 equals to tupa

# %% [markdown]
# #### Count the number of elements in `tup1` and `tup2`. Then add the two counts together and check if the sum is the same as the number of elements in `tup3`.

# %%
# Your code here
tup1_length = len(tup1)
tup2_length = len(tup2)
tup1n2_length = tup1_length + tup2_length
tup3_length = len(tup3)
if tup3_length == tup1n2_length:
    print('tup3 has the same amount of elements as tup1 and tup2 combined.')
# Out:
# tup3 has the same amount of elements as tup1 and tup2 combined.

# %% [markdown]
# #### What is the index number of `"h"` in `tup3`?

# %%
# Your code here
tup3.index('h')
print('Index number of "h" in tup3 is ',tup3.index('h'),'.' )
# Out:
# Index number of "h" in tup3 is  4 .

# %% [markdown]
# #### Now, use a FOR loop to check whether each letter in the following list is present in `tup3`:
#
# ```
# letters = ["a", "b", "c", "d", "e"]
# ```
#
# For each letter you check, print `True` if it is present in `tup3` otherwise print `False`.
#
# *Hint: you only need to loop `letters`. You don't need to loop `tup3` because there is a Python operator `in` you can use. See [reference](https://stackoverflow.com/questions/17920147/how-to-check-if-a-tuple-contains-an-element-in-python).*

# %%
# Your code here
letters = ["a", "b", "c", "d", "e"]
for l in letters:
    if l in tup3:
        print('Ture;', l, 'is in tup3.')
    else:
            print('False;', l, 'is not in tup3.')
# Out:
# Ture; a is in tup3.
# False; b is not in tup3.
# Ture; c is in tup3.
# False; d is not in tup3.
# False; e is not in tup3.

# %% [markdown]
# #### How many times does each letter in `letters` appear in `tup3`?
#
# Print out the number of occurrence of each letter.

# %%
# Your code here
for l in letters:
    print( l, 'in list letters appeared in tup3 ', tup3.count(l), ' time(s).')
# Out:
# a in list letters appeared in tup3  1  time(s).
# b in list letters appeared in tup3  0  time(s).
# c in list letters appeared in tup3  1  time(s).
# d in list letters appeared in tup3  0  time(s).
# e in list letters appeared in tup3  0  time(s).
